# %% [markdown]
# # Chapter 1.2: Variables & Data Types
#
# Back to the course site: https://purwar-lab.github.io/ml-for-robotics-

# %% [markdown]
# Python uses indentation instead of braces, does not require semicolons, and figures out variable types from the values you assign.

# %%
# Robot sensor variables
distance = 2.45          # float - distance in meters
is_obstacle = True       # bool - obstacle detected?
robot_name = "ARIA"      # str - robot's name
wheels = 4               # int - number of wheels

print(type(distance))
print(type(is_obstacle))
print(f"{robot_name} sees an obstacle at {distance:.1f}m: {is_obstacle}")
